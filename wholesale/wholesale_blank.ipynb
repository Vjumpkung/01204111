# %% [markdown]
# # **Wholesale Dataset**

# %% [markdown]
# ไฟล์ "Wholesale customers data.csv" (download จาก https://archive.ics.uci.edu/ml/machine-learning-databases/00292/) เป็นข้อมูลเกี่ยวกับยอดการขายสินค้าประเภทต่างๆ ในแต่ละภูมิภาค ผ่าน 2 ช่องทาง คือ Horeca (Hotel/Restaurant/Cafe) หรือ Retail จาก UCI Machine Learning Repository โดยแถวแรกเป็นชื่อคอลัมน์ และ แถวที่ 2 เป็นต้นไปเก็บข้อมูล
#
# ประเภทของสินค้า คือ fresh products, milk products, grocery products, forzen products, detergents and papers และ delicatessen
#
# คอลัมน์ CHANNEL เป็นช่องทางการขาย ที่มีค่าเป็น Horeca (Hotel/Restaurant/Cafe) หรือ Retail (1,2)
# คอลัมน์ REGION: เป็นภูมิภาค ได้แก่ Lisnon, Oporto หรือ Other (1,2,3)
# คอลัมน์ FRESH, MILK, GROCERY, FROZEN, DETERGENTS_PAPER, DELICATESSEN เป็นยอดขายของสินค้าแต่ละประเภทในภูมิภาคนั้น ผ่านช่องทางนั้นในหนึ่งปี

# %% [markdown]
# 1) เขียนโปรแกรมเพื่อแปลงข้อมูลช่องทางการขายและภูมิภาค จากตัวเลขให้เป็นชื่อของแต่ละช่องทางการขายและภูมิภาคนั้น ๆ จากนั้นบันทึกเป็นไฟล์ใหม่ที่มีชื่อว่า Rename_Wholesale.csv โดยจะใช้ไฟล์นี้เป็นหลักในข้อถัดไป
#
# 2) เขียนโปรแกรมเพื่อหายอดขายรวมจากทุกช่องทาง ในทุกภูมิภาค สำหรับสินค้าแต่ละประเภทแล้ววาด pie chart
#
# 3) เขียนโปรแกรมเพื่อหายอดขายรวมของสินค้าทุกประเภท ในทุกช่องทาง สำหรับแต่ละภูมิภาคแล้ววาด pie chart
#
# 4) เขียนโปรแกรมเพื่อหายอดขายรวมของสินค้าสำหรับทำความสะอาดในแต่ละช่องทางการขาย โดยแบ่งเป็นของแต่ละภูมิภาค พร้อมพล็อตกราฟของแต่ละภูมิภาค
#
# 5) เขียนโปรแกรมเพื่อหาจำนวนคนที่ยอดขายของอาหารสดรวมกับอาหารแช่แข็งผ่านช่องทาง Horeca(Hotel/Restaurant/Cafe) ไม่เกิน 1,000 ชิ้น
#
# 6) เขียนโปรแกรมเพื่อหาภูมิภาคที่มีการบริโภคนมมากที่สุด และในภูมิภาคนั้นมีการบริโภคนมมากกว่าอาหารสดทั้งหมดกี่คน

# %% [markdown]
# ## 0) Prepare data

# %%
with open("wholesale.csv") as fp:
    data = fp.readlines()
    datahead = data[0].strip().split(",")
    datanum = [i.strip().split(",") for i in data[1:]]
    datanum = [[int(j) for j in i] for i in datanum]

# %%
datanum
# Out:
# [[2, 3, 12669, 9656, 7561, 214, 2674, 1338],
#  [2, 3, 7057, 9810, 9568, 1762, 3293, 1776],
#  [2, 3, 6353, 8808, 7684, 2405, 3516, 7844],
#  [1, 3, 13265, 1196, 4221, 6404, 507, 1788],
#  [2, 3, 22615, 5410, 7198, 3915, 1777, 5185],
#  [2, 3, 9413, 8259, 5126, 666, 1795, 1451],
#  [2, 3, 12126, 3199, 6975, 480, 3140, 545],
#  [2, 3, 7579, 4956, 9426, 1669, 3321, 2566],
#  [1, 3, 5963, 3648, 6192, 425, 1716, 750],
#  [2, 3, 6006, 11093, 18881, 1159, 7425, 2098],
#  [2, 3, 3366, 5403, 12974, 4400, 5977, 1744],
#  [2, 3, 13146, 1124, 4523, 1420, 549, 497],
#  [2, 3, 31714, 12319, 11757, 287, 3881, 2931],
#  [2, 3, 21217, 6208, 14982, 3095, 6707, 602],
#  [2, 3, 24653, 9465, 12091, 294, 5058, 2168],
#  [1, 3, 10253, 1114, 3821, 397, 964, 412],
#  [2, 3, 1020, 8816, 12121, 134, 4508, 1080],
#  [1, 3, 5876, 6157, 2933, 839, 370, 4478],
#  [2, 3, 18601, 6327, 10099, 2205, 2767, 3181],
#  [1, 3, 7780, 2495, 9464, 669, 2518, 501],
#  [2, 3, 17546, 4519, 4602, 1066, 2259, 2124],
# ...

# %%
com = []
for i in datanum:
    com.append(dict(zip(datahead,i)))

# %% [markdown]
# ## 1) แปลงข้อมูลช่องทางการขายและภูมิภาค จากตัวเลขให้เป็นชื่อของแต่ละช่องทางการขายและภูมิภาคนั้น ๆ

# %% [markdown]
# คอลัมน์ CHANNEL เป็นช่องทางการขาย ที่มีค่าเป็น Horeca (Hotel/Restaurant/Cafe) หรือ Retail (1,2)
#
# คอลัมน์ REGION: เป็นภูมิภาค ได้แก่ Lisnon, Oporto หรือ Other (1,2,3)

# %%
for i in com:
    if i["Region"] == 1:
        i.update({"Region":"Linson"})
    if i["Region"] == 2:
        i.update({"Region":"Oporto"})
    if i["Region"] == 3:
        i.update({"Region":"Other"})
    if i["Channel"] == 1:
        i.update({"Channel":"Horeca"})
    if i["Channel"] == 2:
        i.update({"Channel":"Retail"})
com
# Out:
# [{'Channel': 'Retail',
#   'Region': 'Other',
#   'Fresh': 12669,
#   'Milk': 9656,
#   'Grocery': 7561,
#   'Frozen': 214,
#   'Detergents_Paper': 2674,
#   'Delicassen': 1338},
#  {'Channel': 'Retail',
#   'Region': 'Other',
#   'Fresh': 7057,
#   'Milk': 9810,
#   'Grocery': 9568,
#   'Frozen': 1762,
#   'Detergents_Paper': 3293,
#   'Delicassen': 1776},
#  {'Channel': 'Retail',
#   'Region': 'Other',
#   'Fresh': 6353,
#   'Milk': 8808,
#   'Grocery': 7684,
#   'Frozen': 2405,
#   'Detergents_Paper': 3516,
#   'Delicassen': 7844},
#  {'Channel': 'Horeca',
#   'Region': 'Other',
#   'Fresh': 13265,
#   'Milk': 1196,
#   'Grocery': 4221,
#   'Frozen': 6404,
#   'Detergents_Paper': 507,
#   'Delicassen': 1788},
#  {'Channel': 'Retail',
#   'Region': 'Other',
#   'Fresh': 22615,
#   'Milk': 5410,
#   'Grocery': 7198,
#   'Frozen': 3915,
#   'Detergents_Paper': 1777,
#   'Delicassen': 5185},
#  {'Channel': 'Retail',
#   'Region': 'Other',
#   'Fresh': 9413,
#   'Milk': 8259,
# ...

# %% [markdown]
# ## 2) หายอดขายรวมจากทุกช่องทาง ในทุกภูมิภาค สำหรับสินค้าแต่ละประเภท

# %% [markdown]
# ```
# Fresh               5280131
# Milk                2550357
# Grocery             3498562
# Frozen              1351650
# Detergents_Paper    1267857
# Delicassen          670943
# ```

# %%
sales = {}
for i in com[0]:
    if i in ("Channel","Region") : continue
    sum_per_col = 0
    for j in com:
        sum_per_col += j[i]
    sales.setdefault(i,sum_per_col)
sales
# Out:
# {'Fresh': 5280131,
#  'Milk': 2550357,
#  'Grocery': 3498562,
#  'Frozen': 1351650,
#  'Detergents_Paper': 1267857,
#  'Delicassen': 670943}

# %%
for i,j in list(sales.items()):
    print(f"{i:<19} {j}")
# Out:
# Fresh               5280131
# Milk                2550357
# Grocery             3498562
# Frozen              1351650
# Detergents_Paper    1267857
# Delicassen          670943

# %% [markdown]
# ## 3) หายอดขายรวมของสินค้าทุกประเภท ในทุกช่องทาง สำหรับแต่ละภูมิภาค

# %% [markdown]
# ```
# Other 10677599
# Lisnon 2386813
# Oporto 1555088
# ```

# %%
sales_every = {}
for i in com:
    if i["Region"] not in sales_every:
        sales_every.setdefault(i["Region"],sum(list(i.values())[2:]))
    else:
        sales_every[i["Region"]] += sum(list(i.values())[2:])
for i in sorted(sales_every.items(),reverse=True,key=lambda x : x[1]):
    print(*i)
# Out:
# Other 10677599
# Linson 2386813
# Oporto 1555088

# %% [markdown]
# ## 4) เขียนโปรแกรมเพื่อหายอดขายรวมของสินค้าสำหรับทำความสะอาด(Detergents_Paper) ในแต่ละช่องทางการขาย โดยแบ่งเป็นของแต่ละภูมิภาค

# %% [markdown]
# ```
# Other
# Horeca 165990
# Retail 724420
#
# Lisnon
# Horeca 56081
# Retail 148055
#
# Oporto
# Horeca 13516
# Retail 159795
# ```

# %%
ex = {'Channel': 'Retail', 'Region': 'Other', 'Fresh': 12669, 'Milk': 9656, 'Grocery': 7561, 'Frozen': 214, 'Detergents_Paper': 2674, 'Delicassen': 1338}
new_dick = {}
new_dick.setdefault(ex["Channel"], {})
new_dick[ex["Channel"]].setdefault(ex["Region"],1)
new_dick
# Out:
# {'Retail': {'Other': 1}}

# %%
de_list = {}
for i in com:
    if i["Region"] not in de_list:
        de_list.setdefault(i["Region"],{})
    if i["Channel"] not in de_list[i["Region"]]:
        de_list[i["Region"]].setdefault(i["Channel"],i["Detergents_Paper"])
    else:
        de_list[i["Region"]][i["Channel"]] += i["Detergents_Paper"]
de_list
# Out:
# {'Other': {'Retail': 724420, 'Horeca': 165990},
#  'Linson': {'Horeca': 56081, 'Retail': 148055},
#  'Oporto': {'Retail': 159795, 'Horeca': 13516}}

# %%
for i in de_list.items():
    print(i[0])
    for j in sorted(list(i[1].items())):
        print(*j)
# Out:
# Other
# Horeca 165990
# Retail 724420
# Linson
# Horeca 56081
# Retail 148055
# Oporto
# Horeca 13516
# Retail 159795

# %% [markdown]
# ## 5) จำนวนคนที่ยอดขายของอาหารสดรวมกับอาหารแช่แข็งผ่านช่องทาง Horeca(Hotel/Restaurant/Cafe) ไม่เกิน 1,000 ชิ้น

# %% [markdown]
# ```
# 10
# ```

# %%
kor5 = 0
for i in com:
    if (i["Channel"] == "Horeca") and ((i["Fresh"]+i["Frozen"]) <= 1000):
        kor5 += 1
kor5
# Out:
# 10

# %% [markdown]
# ## 6) เขียนโปรแกรมเพื่อหาภูมิภาคที่มีการบริโภค นม มากที่สุด และในภูมิภาคนั้นมีการบริโภค นม มากกว่าอาหารสดทั้งหมดกี่คน

# %% [markdown]
# ```
# ภูมิภาคที่มีการบริโภค นม มากที่สุด
# Other: 1888759
#
# ภูมิภาคนั้นมีการบริโภค นม มากกว่าอาหารสดทั้งหมดกี่คน
# 107
# ```

# %%
nom = {}
for i in com:
    if i["Region"] not in nom:
        nom.setdefault(i["Region"],i["Milk"])
    else:
        nom[i["Region"]] += i["Milk"]
most_nom = max(nom.items(),key=lambda x : x[1])
print(f"{most_nom[0]}: {most_nom[1]}")
# Out:
# Other: 1888759

# %%
fresh_food = 0
for i in com:
    if i["Region"] == "Other" and i["Milk"] > i["Fresh"]:
        fresh_food += 1
print(fresh_food)
# Out:
# 107
