# %%
import json
with open("message.json",encoding="utf8") as fp:
    data = json.load(fp)
data
# Out:
# [{'student_id': '6410500173',
#   'thai_name': 'นางสาวกวินธิดา ปิ่นทอง',
#   'english_name': 'MissKawintida  PINTHONG',
#   'nickname': 'ฟอร์แทรน',
#   'telephone_number': '',
#   'university_email': 'kawintida.pi@ku.th'},
#  {'student_id': '6410500181',
#   'thai_name': 'นายจิรัฏฐ์ มีวาสนา',
#   'english_name': 'MisterJIRAT MEEWASSANA',
#   'nickname': 'อิคคิว',
#   'telephone_number': '093-594-9158',
#   'university_email': 'jirat.m@ku.th'},
#  {'student_id': '6410500190',
#   'thai_name': 'นางสาวชนากานต์ ศรีอุดม',
#   'english_name': 'MissCHANAKARN SRIUDOM',
#   'nickname': 'ทราย',
#   'telephone_number': '',
#   'university_email': 'chanakarn.sriu@ku.th'},
#  {'student_id': '6410500203',
#   'thai_name': 'นายชัยพจน์ ก้องจันทร์สว่าง',
#   'english_name': 'MisterChaipot KONGJANSAWANG',
#   'nickname': 'ต้น',
#   'telephone_number': '',
#   'university_email': 'chaipot.k@ku.th'},
#  {'student_id': '6410500211',
#   'thai_name': 'นายญาโณทัย ไชยธวัช',
# ...
